# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict, Annotated
from langchain_core.messages import BaseMessage, HumanMessage
from langgraph.graph.message import add_messages
from langchain_ollama import ChatOllama

# %%
llm = ChatOllama(model="qwen3:4b")

# %%
class state(TypedDict):
    messages= Annotated[list[BaseMessage], add_messages]

# %%
# !pip install langgraph
# Out:
# Requirement already satisfied: langgraph in /Users/asmitkaushal/ml_env/lib/python3.12/site-packages (1.2.4)
# Requirement already satisfied: langchain-core<2,>=1.4.0 in /Users/asmitkaushal/ml_env/lib/python3.12/site-packages (from langgraph) (1.4.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in /Users/asmitkaushal/ml_env/lib/python3.12/site-packages (from langgraph) (4.1.1)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in /Users/asmitkaushal/ml_env/lib/python3.12/site-packages (from langgraph) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in /Users/asmitkaushal/ml_env/lib/python3.12/site-packages (from langgraph) (0.4.2)
# Requirement already satisfied: pydantic>=2.7.4 in /Users/asmitkaushal/ml_env/lib/python3.12/site-packages (from langgraph) (2.13.4)
# Requirement already satisfied: xxhash>=3.5.0 in /Users/asmitkaushal/ml_env/lib/python3.12/site-packages (from langgraph) (3.7.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/asmitkaushal/ml_env/lib/python3.12/site-packages (from langchain-core<2,>=1.4.0->langgraph) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.14 in /Users/asmitkaushal/ml_env/lib/python3.12/site-packages (from langchain-core<2,>=1.4.0->langgraph) (0.0.16)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /Users/asmitkaushal/ml_env/lib/python3.12/site-packages (from langchain-core<2,>=1.4.0->langgraph) (0.8.7)
# Requirement already satisfied: packaging>=23.2.0 in /Users/asmitkaushal/ml_env/lib/python3.12/site-packages (from langchain-core<2,>=1.4.0->langgraph) (26.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /Users/asmitkaushal/ml_env/lib/python3.12/site-packages (from langchain-core<2,>=1.4.0->langgraph) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/asmitkaushal/ml_env/lib/python3.12/site-packages (from langchain-core<2,>=1.4.0->langgraph) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/asmitkaushal/ml_env/lib/python3.12/site-packages (from langchain-core<2,>=1.4.0->langgraph) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Users/asmitkaushal/ml_env/lib/python3.12/site-packages (from langchain-core<2,>=1.4.0->langgraph) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/asmitkaushal/ml_env/lib/python3.12/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2,>=1.4.0->langgraph) (3.0.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /Users/asmitkaushal/ml_env/lib/python3.12/site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in /Users/asmitkaushal/ml_env/lib/python3.12/site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in /Users/asmitkaushal/ml_env/lib/python3.12/site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph) (3.11.9)
# Requirement already satisfied: websockets<16,>=14 in /Users/asmitkaushal/ml_env/lib/python3.12/site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph) (15.0.1)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/asmitkaushal/ml_env/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.0->langgraph) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /Users/asmitkaushal/ml_env/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.0->langgraph) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/asmitkaushal/ml_env/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.0->langgraph) (0.25.0)
# Requirement already satisfied: anyio in /Users/asmitkaushal/ml_env/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph) (4.12.1)
# Requirement already satisfied: certifi in /Users/asmitkaushal/ml_env/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /Users/asmitkaushal/ml_env/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph) (1.0.9)
# Requirement already satisfied: idna in /Users/asmitkaushal/ml_env/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/asmitkaushal/ml_env/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/asmitkaushal/ml_env/lib/python3.12/site-packages (from pydantic>=2.7.4->langgraph) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /Users/asmitkaushal/ml_env/lib/python3.12/site-packages (from pydantic>=2.7.4->langgraph) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/asmitkaushal/ml_env/lib/python3.12/site-packages (from pydantic>=2.7.4->langgraph) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/asmitkaushal/ml_env/lib/python3.12/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.0->langgraph) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/asmitkaushal/ml_env/lib/python3.12/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.0->langgraph) (2.6.3)
#
# [notice] A new release of pip is available: 25.3 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip
